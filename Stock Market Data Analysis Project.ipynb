# %%
import pandas as pd
from pandas import Series, DataFrame
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline

# %%
from pandas.io.data import DataReader
# Out:
# /Users/smartlab/anaconda2/lib/python2.7/site-packages/pandas/io/data.py:33: FutureWarning:
# The pandas.io.data module is moved to a separate package (pandas-datareader) and will be removed from pandas in a future version.
# After installing the pandas-datareader package (https://github.com/pydata/pandas-datareader), you can change the import ``from pandas.io import data, wb`` to ``from pandas_datareader import data, wb``.
#   FutureWarning)

# %%
from datetime import datetime

# %%
from __future__ import division

# %%
tech_list = ['AAPL','GOOG','MSFT','AMZN']

# %%
end = datetime.now()

start = datetime(end.year-1, end.month, end.day)

# %%
for stock in tech_list:
    globals()[stock] = DataReader(stock,'yahoo',start,end)

# %%
AAPL
# Out:
#                   Open        High         Low       Close     Volume  \
# Date
# 2015-06-11  129.179993  130.179993  128.479996  128.589996   35390900
# 2015-06-12  128.190002  128.330002  127.110001  127.169998   36886200
# 2015-06-15  126.099998  127.239998  125.709999  126.919998   43988900
# 2015-06-16  127.029999  127.849998  126.370003  127.599998   31494100
# 2015-06-17  127.720001  127.879997  126.739998  127.300003   32918100
# 2015-06-18  127.230003  128.309998  127.220001  127.879997   35407200
# 2015-06-19  127.709999  127.820000  126.400002  126.599998   54716900
# 2015-06-22  127.489998  128.059998  127.080002  127.610001   34039300
# 2015-06-23  127.480003  127.610001  126.879997  127.029999   30268900
# 2015-06-24  127.209999  129.800003  127.120003  128.110001   55280900
# 2015-06-25  128.860001  129.199997  127.500000  127.500000   31938100
# 2015-06-26  127.669998  127.989998  126.510002  126.750000   44066800
# 2015-06-29  125.459999  126.470001  124.480003  124.529999   49161400
# 2015-06-30  125.570000  126.120003  124.860001  125.430000   44370700
# 2015-07-01  126.900002  126.940002  125.989998  126.599998   30238800
# 2015-07-02  126.430000  126.690002  125.769997  126.440002   27211000
# 2015-07-06  124.940002  126.230003  124.849998  126.000000   28060400
# 2015-07-07  125.889999  126.150002  123.769997  125.690002   46946800
# 2015-07-08  124.480003  124.639999  122.540001  122.570000   60761600
# 2015-07-09  123.849998  124.059998  119.220001  120.070000   77821600
# 2015-07-10  121.940002  123.849998  121.209999  123.279999   61354500
# 2015-07-13  125.029999  125.760002  124.320000  125.660004   41440500
# 2015-07-14  126.040001  126.370003  125.040001  125.610001   31768100
# 2015-07-15  125.720001  127.150002  125.580002  126.820000   33649200
# 2015-07-16  127.739998  128.570007  127.349998  128.509995   36222400
# 2015-07-17  129.080002  129.619995  128.309998  129.619995   46164700
# 2015-07-20  130.970001  132.970001  130.699997  132.070007   58900200
# 2015-07-21  132.850006  132.919998  130.320007  130.750000   76756400
# 2015-07-22  121.989998  125.500000  121.989998  125.220001  115450600
# 2015-07-23  126.199997  127.089996  125.059998  125.160004   50999500
# ...                ...         ...         ...         ...        ...
# 2016-04-29   93.989998   94.720001   92.510002   93.739998   68531500
# 2016-05-02   93.970001   94.080002   92.400002   93.639999   48160100
# 2016-05-03   94.199997   95.739998   93.680000   95.180000   56831300
# 2016-05-04   95.199997   95.900002   93.820000   94.190002   41025500
# 2016-05-05   94.000000   94.070000   92.680000   93.239998   35890500
# 2016-05-06   93.370003   93.449997   91.849998   92.720001   43458200
# 2016-05-09   93.000000   93.769997   92.589996   92.790001   32855300
# 2016-05-10   93.330002   93.570000   92.110001   93.419998   33592500
# 2016-05-11   93.480003   93.570000   92.459999   92.510002   28539900
# 2016-05-12   92.720001   92.779999   89.470001   90.339996   76109800
# 2016-05-13   90.000000   91.669998   90.000000   90.519997   44188200
# 2016-05-16   92.389999   94.389999   91.650002   93.879997   61140600
# 2016-05-17   94.550003   94.699997   93.010002   93.489998   46507400
# 2016-05-18   94.160004   95.209999   93.889999   94.559998   41923100
# 2016-05-19   94.639999   94.639999   93.570000   94.199997   30342700
# 2016-05-20   94.639999   95.430000   94.519997   95.220001   31804600
# 2016-05-23   95.870003   97.190002   95.669998   96.430000   37860500
# 2016-05-24   97.220001   98.089996   96.839996   97.900002   35036800
# 2016-05-25   98.669998   99.739998   98.110001   99.620003   38168800
# 2016-05-26   99.680000  100.730003   98.639999  100.410004   56093400
# 2016-05-27   99.440002  100.470001   99.250000  100.349998   36229500
# 2016-05-31   99.599998  100.400002   98.820000   99.860001   42084800
# 2016-06-01   99.019997   99.540001   98.330002   98.459999   29113400
# 2016-06-02   97.599998   97.839996   96.629997   97.720001   40004100
# 2016-06-03   97.790001   98.269997   97.449997   97.919998   28062900
# 2016-06-06   97.989998  101.889999   97.550003   98.629997   23242200
# 2016-06-07   99.250000   99.870003   98.959999   99.029999   22366400
# 2016-06-08   99.019997   99.559998   98.680000   98.940002   20812700
# 2016-06-09   98.500000   99.989998   98.459999   99.650002   26419600
# 2016-06-10   98.529999   99.349998   98.480003   98.830002   31462100
#
#              Adj Close
# Date
# 2015-06-11  126.009814
# 2015-06-12  124.618308
# 2015-06-15  124.373324
# 2015-06-16  125.039680
# 2015-06-17  124.745705
# 2015-06-18  125.314061
# 2015-06-19  124.059746
# 2015-06-22  125.049482
# 2015-06-23  124.481118
# 2015-06-24  125.539449
# 2015-06-25  124.941688
# 2015-06-26  124.206737
# 2015-06-29  122.031281
# 2015-06-30  122.913224
# 2015-07-01  124.059746
# 2015-07-02  123.902960
# 2015-07-06  123.471786
# 2015-07-07  123.168009
# 2015-07-08  120.110610
# 2015-07-09  117.660773
# 2015-07-10  120.806362
# 2015-07-13  123.138612
# 2015-07-14  123.089612
# 2015-07-15  124.275333
# 2015-07-16  125.931417
# 2015-07-17  127.019145
# 2015-07-20  129.419998
# 2015-07-21  128.126477
# 2015-07-22  122.707438
# 2015-07-23  122.648645
# ...                ...
# 2016-04-29   93.172721
# 2016-05-02   93.073328
# 2016-05-03   94.604009
# 2016-05-04   93.620002
# 2016-05-05   93.239998
# 2016-05-06   92.720001
# 2016-05-09   92.790001
# 2016-05-10   93.419998
# 2016-05-11   92.510002
# 2016-05-12   90.339996
# 2016-05-13   90.519997
# 2016-05-16   93.879997
# 2016-05-17   93.489998
# 2016-05-18   94.559998
# 2016-05-19   94.199997
# 2016-05-20   95.220001
# 2016-05-23   96.430000
# 2016-05-24   97.900002
# 2016-05-25   99.620003
# 2016-05-26  100.410004
# 2016-05-27  100.349998
# 2016-05-31   99.860001
# 2016-06-01   98.459999
# 2016-06-02   97.720001
# 2016-06-03   97.919998
# 2016-06-06   98.629997
# 2016-06-07   99.029999
# 2016-06-08   98.940002
# 2016-06-09   99.650002
# 2016-06-10   98.830002
#
# [253 rows x 6 columns]

# %%
GOOG.head()
# Out:
#                   Open        High         Low       Close   Volume  \
# Date
# 2015-06-11  538.424988  538.979980  533.020020  534.609985  1217500
# 2015-06-12  531.599976  533.119995  530.159973  532.330017   955800
# 2015-06-15  528.000000  528.299988  524.000000  527.200012  1632700
# 2015-06-16  528.400024  529.640015  525.559998  528.150024  1071800
# 2015-06-17  529.369995  530.979980  525.099976  529.260010  1294200
#
#              Adj Close
# Date
# 2015-06-11  534.609985
# 2015-06-12  532.330017
# 2015-06-15  527.200012
# 2015-06-16  528.150024
# 2015-06-17  529.260010

# %%
AAPL.describe()
# Out:
#              Open        High         Low       Close        Volume  \
# count  253.000000  253.000000  253.000000  253.000000  2.530000e+02
# mean   109.546047  110.617312  108.376482  109.508814  4.756856e+07
# std     10.461017   10.381165   10.468565   10.391424  2.109969e+07
# min     90.000000   91.669998   89.470001   90.339996  1.304640e+07
# 25%     99.440002  100.769997   98.639999   99.959999  3.325730e+07
# 50%    110.230003  111.739998  108.980003  110.209999  4.334120e+07
# 75%    116.580002  117.699997  115.500000  116.410004  5.528090e+07
# max    132.850006  132.970001  130.699997  132.070007  1.622063e+08
#
#         Adj Close
# count  253.000000
# mean   108.220247
# std      9.742338
# min     90.339996
# 25%     99.620003
# 50%    108.896984
# 75%    114.843813
# max    129.419998

# %%
AAPL.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 253 entries, 2015-06-11 to 2016-06-10
# Data columns (total 6 columns):
# Open         253 non-null float64
# High         253 non-null float64
# Low          253 non-null float64
# Close        253 non-null float64
# Volume       253 non-null int64
# Adj Close    253 non-null float64
# dtypes: float64(5), int64(1)
# memory usage: 13.8 KB

# %%
AAPL['Adj Close'].plot(legend = True, figsize = (10,4))

# %%
AAPL['Volume'].plot(legend = True, figsize = (10,4))

# %%
#For more info on the moving average check out the following links:
#http://www.investopedia.com/terms/m/movingaverage.asp
#http://www.investopedia.com/articles/active-trading/052014/how-use-moving-average-buy-stocks.asp

# %%
ma_day = [10, 20, 50]

for ma in ma_day:
    column_name = "MA for %s days" %(str(ma))
    
    AAPL[column_name] = pd.rolling_mean(AAPL['Adj Close'], ma)

# %%
AAPL[['Adj Close','MA for 10 days','MA for 20 days', 'MA for 50 days']].plot(subplots=False, figsize=(10,4))

# %%
AAPL['Daily Return'] = AAPL['Adj Close'].pct_change()

AAPL['Daily Return'].plot(figsize=(10,4),legend=True,linestyle='--',marker='o')

# %%
sns.distplot(AAPL['Daily Return'].dropna(),bins=100,color='purple')

# %%
AAPL['Daily Return'].hist(bins=100)

# %%
closing_df = DataReader(tech_list, 'yahoo', start, end)['Adj Close']

# %%
closing_df.head()
# Out:
#                   AAPL        AMZN        GOOG       MSFT
# Date
# 2015-06-11  126.009814  432.970001  534.609985  45.184156
# 2015-06-12  124.618308  429.920013  532.330017  44.726868
# 2015-06-15  124.373324  423.670013  527.200012  44.250117
# 2015-06-16  125.039680  427.260010  528.150024  44.590655
# 2015-06-17  124.745705  427.809998  529.260010  44.726868

# %%
tech_rets = closing_df.pct_change()

# %%
tech_rets.head()
# Out:
#                 AAPL      AMZN      GOOG      MSFT
# Date
# 2015-06-11       NaN       NaN       NaN       NaN
# 2015-06-12 -0.011043 -0.007044 -0.004265 -0.010121
# 2015-06-15 -0.001966 -0.014538 -0.009637 -0.010659
# 2015-06-16  0.005358  0.008474  0.001802  0.007696
# 2015-06-17 -0.002351  0.001287  0.002102  0.003055

# %%
sns.jointplot('GOOG', 'GOOG', tech_rets, kind = 'scatter', color = 'seagreen')

# %%
sns.jointplot('GOOG', 'MSFT', tech_rets, kind = 'scatter')

# %%
tech_rets.head()
# Out:
#                 AAPL      AMZN      GOOG      MSFT
# Date
# 2015-06-11       NaN       NaN       NaN       NaN
# 2015-06-12 -0.011043 -0.007044 -0.004265 -0.010121
# 2015-06-15 -0.001966 -0.014538 -0.009637 -0.010659
# 2015-06-16  0.005358  0.008474  0.001802  0.007696
# 2015-06-17 -0.002351  0.001287  0.002102  0.003055

# %%
sns.pairplot(tech_rets.dropna())

# %%
returns_fig = sns.PairGrid(tech_rets.dropna())

returns_fig.map_upper(plt.scatter, color = 'purple')

returns_fig.map_lower(sns.kdeplot, cmap = 'cool_d')

returns_fig.map_diag(plt.hist, bins = 30)

# %%
returns_fig = sns.PairGrid(closing_df)

returns_fig.map_upper(plt.scatter, color = 'purple')

returns_fig.map_lower(sns.kdeplot, cmap = 'cool_d')

returns_fig.map_diag(plt.hist, bins = 30)

# %%
sns.corrplot(tech_rets.dropna(),annot=True)
# Out:
# /Users/smartlab/anaconda2/lib/python2.7/site-packages/seaborn/linearmodels.py:1285: UserWarning: The `corrplot` function has been deprecated in favor of `heatmap` and will be removed in a forthcoming release. Please update your code.
#   warnings.warn(("The `corrplot` function has been deprecated in favor "
# /Users/smartlab/anaconda2/lib/python2.7/site-packages/seaborn/linearmodels.py:1351: UserWarning: The `symmatplot` function has been deprecated in favor of `heatmap` and will be removed in a forthcoming release. Please update your code.
#   warnings.warn(("The `symmatplot` function has been deprecated in favor "

# %%
rets = tech_rets.dropna()

# %%
area = np.pi*20

plt.scatter(rets.mean(), rets.std(), s = area)

plt.xlabel('Expected Return')
plt.ylabel('Risk')

for label, x, y in zip(rets.columns, rets.mean(), rets.std()):
    plt.annotate(
        label,
        xy = (x,y), xytest = (50,50),
        textcoords = 'offset points', ha = 'right', va = 'bottom',
        arrowprops = dict(arrowstyle = "-", connectionstyle = "arc3"))
    
    plt.xlim(-0.015, 0.015)
    plt.ylim(-0.005, 0.04)
# Out:
# /Users/smartlab/anaconda2/lib/python2.7/site-packages/matplotlib/text.py:2046: UserWarning: You have used the `textcoords` kwarg, but not the `xytext` kwarg.  This can lead to surprising results.
#   warnings.warn("You have used the `textcoords` kwarg, but not "
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-bd08c526b073> in <module>()
#      11         xy = (x,y), xytest = (50,50),
#      12         textcoords = 'offset points', ha = 'right', va = 'bottom',
# ---> 13         arrowprops = dict(arrowstyle = "-", connectionstyle = "arc3"))
#      14
#      15     plt.xlim(-0.015, 0.015)
#
# /Users/smartlab/anaconda2/lib/python2.7/site-packages/matplotlib/pyplot.pyc in annotate(*args, **kwargs)
#    3572 @docstring.copy_dedent(Axes.annotate)
#    3573 def annotate(*args, **kwargs):
# -> 3574     ret = gca().annotate(*args, **kwargs)
#    3575     return ret
#    3576
#
# /Users/smartlab/anaconda2/lib/python2.7/site-packages/matplotlib/axes/_axes.pyc in annotate(self, *args, **kwargs)
#     672         .. plot:: mpl_examples/pylab_examples/annotation_demo2.py
#     673         """
# --> 674         a = mtext.Annotation(*args, **kwargs)
#     675         a.set_transform(mtransforms.IdentityTransform())
#     676         if 'clip_on' in kwargs:
#
# /Users/smartlab/anaconda2/lib/python2.7/site-packages/matplotlib/text.pyc in __init__(self, s, xy, xytext, xycoords, textcoords, arrowprops, annotation_clip, **kwargs)
#    2058         x, y = xytext
#    2059
# -> 2060         Text.__init__(self, x, y, s, **kwargs)
#    2061
#    2062         self.arrowprops = arrowprops
#
# /Users/smartlab/anaconda2/lib/python2.7/site-packages/matplotlib/text.pyc in __init__(self, x, y, text, color, verticalalignment, horizontalalignment, multialignment, fontproperties, rotation, linespacing, rotation_mode, usetex, wrap, **kwargs)
#     233         self._linespacing = linespacing
#     234         self.set_rotation_mode(rotation_mode)
# --> 235         self.update(kwargs)
#     236
#     237     def update(self, kwargs):
#
# /Users/smartlab/anaconda2/lib/python2.7/site-packages/matplotlib/text.pyc in update(self, kwargs)
#     240         """
#     241         bbox = kwargs.pop('bbox', None)
# --> 242         super(Text, self).update(kwargs)
#     243         if bbox:
#     244             self.set_bbox(bbox)  # depends on font properties
#
# /Users/smartlab/anaconda2/lib/python2.7/site-packages/matplotlib/artist.pyc in update(self, props)
#     854                 func = getattr(self, 'set_' + k, None)
#     855                 if func is None or not six.callable(func):
# --> 856                     raise AttributeError('Unknown property %s' % k)
#     857                 func(v)
#     858             changed = True
#
# AttributeError: Unknown property xytest

# %%
sns.distplot(AAPL['Daily Return'].dropna(), bins = 100, color = 'purple')

# %%
rets.head()
# Out:
#                 AAPL      AMZN      GOOG      MSFT
# Date
# 2015-06-12 -0.011043 -0.007044 -0.004265 -0.010121
# 2015-06-15 -0.001966 -0.014538 -0.009637 -0.010659
# 2015-06-16  0.005358  0.008474  0.001802  0.007696
# 2015-06-17 -0.002351  0.001287  0.002102  0.003055
# 2015-06-18  0.004556  0.027068  0.014114  0.016315

# %%
rets['AAPL'].quantile(0.05)
# Out:
# -0.028031891283851848

# %%
days = 365

dt = 1/days

mu = rets.mean()['GOOG']

sigma = rets.std()['GOOG']

# %%
def stock_monte_carlo(start_price, days, mu, sigma):
    
    price = np.zeros(days)
    price[0] = start_price
    
    shock = np.zeros(days)
    drift = np.zeros(days)
    
    for x in range(1, days):
        
        shock[x] = np.random.normal(loc=mu*dt, scale=sigma*np.sqrt(dt))
        
        drift[x] = mu*dt
        
        price[x] = price[x-1] + (price[x-1]*(drift[x] + shock[x]))
        
    return price

# %%
GOOG.head()
# Out:
#                   Open        High         Low       Close   Volume  \
# Date
# 2015-06-11  538.424988  538.979980  533.020020  534.609985  1217500
# 2015-06-12  531.599976  533.119995  530.159973  532.330017   955800
# 2015-06-15  528.000000  528.299988  524.000000  527.200012  1632700
# 2015-06-16  528.400024  529.640015  525.559998  528.150024  1071800
# 2015-06-17  529.369995  530.979980  525.099976  529.260010  1294200
#
#              Adj Close
# Date
# 2015-06-11  534.609985
# 2015-06-12  532.330017
# 2015-06-15  527.200012
# 2015-06-16  528.150024
# 2015-06-17  529.260010

# %%
start_price = 540.74

for run in xrange(100):
    plt.plot(stock_monte_carlo(start_price, days, mu, sigma))
    
plt.xlabel('Days')
plt.ylabel('Price')
plt.title('Monte Carlo Analysis for Google')

# %%
runs = 10000

simulations = np.zeros(runs)

for run in xrange(runs):
    simulations[run] = stock_monte_carlo(start_price, days, mu, sigma)[days-1]

# %%
q = np.percentile(simulations, 1)

plt.hist(simulations,bins=200)

plt.figtext(0.6,0.8, s="Start price: $%.2f" %start_price)

plt.figtext(0.6, 0.7, "Mean final price: $%.2f" % simulations.mean())

plt.figtext(0.6, 0.6, "VaR(0.99): $%.2f" % (start_price - q,))

plt.figtext(0.15, 0.6, "q(0.99): $%.2f" % q)

plt.axvline(x=q, linewidth=4, color='r')

plt.title(u"Final price distribution for Google Stock after %s days" % days, weight='bold')
